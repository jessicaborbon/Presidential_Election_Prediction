# %% [markdown]
# ## Create 2022Age Census Demo CSV

# %%
import pandas as pd

# %%
# For comma-separated values
age_2022_df = pd.read_csv('../censusoutputcsv/2022_census_age.csv', sep=',')

# %%
# Display dataframe head
age_2022_df.head()
# Out:
#       state  18_and_over_population_male  18_and_over_population_female  \
# 0   Alabama                         47.6                           52.4
# 1   Alabama                         47.5                           52.5
# 2   Alabama                         47.7                           52.3
# 3   Alabama                         48.3                           51.7
# 4   Alabama                         48.7                           51.3
#
#    20_to_24_years\t  25_to_34_years  35_to_44_years  45_to_54_years  \
# 0               5.8            12.8            12.0            12.5
# 1               6.1            13.8            12.4            11.9
# 2               8.0            12.4            12.2            12.1
# 3               6.3            11.8            12.5            12.3
# 4               6.4            13.1            12.8            12.5
#
#    55_to_59_years  60_to_64_years\t  65_to_74_years\t  75_to_84_years\t  \
# 0             6.0               7.2              11.5               5.9
# 1             6.5               6.3              10.6               5.9
# 2             6.5               6.7              11.2               5.6
# 3             6.7               6.5              11.2               6.0
# 4             6.5               7.5              10.1               5.6
#
#    85_years_and_over\t  median_age(years)\t  state_id  congressional_district  \
# 0                  2.0                 40.9         1                       1
# 1                  1.6                 39.1         1                       2
# 2                  1.5                 39.4         1                       3
# 3                  1.7                 40.8         1                       4
# 4                  1.6                 40.2         1                       5
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
# Remove unnecessary spaces
age_2022_df.columns = age_2022_df.columns.str.strip()

# %%
# Check dataframe columns
age_2022_df.columns
# Out:
# Index(['state', '18_and_over_population_male', '18_and_over_population_female',
#        '20_to_24_years', '25_to_34_years', '35_to_44_years', '45_to_54_years',
#        '55_to_59_years', '60_to_64_years', '65_to_74_years', '75_to_84_years',
#        '85_years_and_over', 'median_age(years)', 'state_id',
#        'congressional_district', 'year'],
#       dtype='object')

# %%
# Check dataframe types
age_2022_df.dtypes
# Out:
# state                             object
# 18_and_over_population_male      float64
# 18_and_over_population_female    float64
# 20_to_24_years                   float64
# 25_to_34_years                   float64
# 35_to_44_years                   float64
# 45_to_54_years                   float64
# 55_to_59_years                   float64
# 60_to_64_years                   float64
# 65_to_74_years                   float64
# 75_to_84_years                   float64
# 85_years_and_over                float64
# median_age(years)                float64
# state_id                           int64
# congressional_district             int64
# year                               int64
# dtype: object

# %%
# Drop 'state_id' and 'congressional_district' columns
age_2022_df = age_2022_df.drop(columns=['state_id', 'congressional_district'])

# Display the updated DataFrame
age_2022_df
# Out:
#             state  18_and_over_population_male  18_and_over_population_female  \
# 0         Alabama                         47.6                           52.4
# 1         Alabama                         47.5                           52.5
# 2         Alabama                         47.7                           52.3
# 3         Alabama                         48.3                           51.7
# 4         Alabama                         48.7                           51.3
# ..            ...                          ...                            ...
# 432     Wisconsin                         50.4                           49.6
# 433     Wisconsin                         50.7                           49.3
# 434     Wisconsin                         50.0                           50.0
# 435       Wyoming                         51.0                           49.0
# 436   Puerto Rico                         46.6                           53.4
#
#      20_to_24_years  25_to_34_years  35_to_44_years  45_to_54_years  \
# 0               5.8            12.8            12.0            12.5
# 1               6.1            13.8            12.4            11.9
# 2               8.0            12.4            12.2            12.1
# 3               6.3            11.8            12.5            12.3
# 4               6.4            13.1            12.8            12.5
# ..              ...             ...             ...             ...
# 432             6.3            11.6            12.3            12.0
# 433             4.9            10.5            11.8            12.0
# 434             5.7            12.2            12.6            12.1
# 435             6.3            12.5            14.0            11.1
# 436             6.7            12.6            12.4            12.6
#
#      55_to_59_years  60_to_64_years  65_to_74_years  75_to_84_years  \
# 0               6.0             7.2            11.5             5.9
# 1               6.5             6.3            10.6             5.9
# 2               6.5             6.7            11.2             5.6
# 3               6.7             6.5            11.2             6.0
# 4               6.5             7.5            10.1             5.6
# ..              ...             ...             ...             ...
# 432             6.9             7.9            12.0             6.2
# 433             7.5             8.4            13.6             6.8
# 434             7.4             7.2            11.4             5.4
# 435             6.0             6.6            11.8             5.4
# 436             6.7             6.9            11.9             8.6
#
#      85_years_and_over  median_age(years)  year
# 0                  2.0               40.9  2022
# 1                  1.6               39.1  2022
# 2                  1.5               39.4  2022
# 3                  1.7               40.8  2022
# 4                  1.6               40.2  2022
# ..                 ...                ...   ...
# 432                2.3               42.7  2022
# 433                2.2               45.4  2022
# 434                2.0               41.3  2022
# 435                1.4               39.1  2022
# 436                3.0               44.7  2022
#
# [437 rows x 14 columns]

# %%
# Check for null values in the entire DataFrame
null_values = age_2022_df.isnull().sum()

# Display columns with null values
print(null_values[null_values > 0])
# Out:
# Series([], dtype: int64)

# %%
# Group by 'State' and calculate the median of 'Median_Age' to reduce rows 
st_medians_df = age_2022_df.groupby('state')['median_age(years)'].median().reset_index()

st_medians_df['median_age(years)'] = st_medians_df['median_age(years)'].astype(int)

# Rename the columns if desired
st_medians_df.columns = ['state', 'median_age(years)']

# Display the results
print(st_medians_df)
# Out:
#                     state  median_age(years)
# 0                 Alabama                 39
# 1                  Alaska                 35
# 2                 Arizona                 41
# 3                Arkansas                 39
# 4              California                 38
# 5                Colorado                 37
# 6             Connecticut                 40
# 7                Delaware                 41
# 8    District of Columbia                 34
# 9                 Florida                 42
# 10                Georgia                 37
# 11                 Hawaii                 40
# 12                  Idaho                 37
# 13               Illinois                 40
# 14                Indiana                 38
# 15                   Iowa                 39
# 16                 Kansas                 37
# 17               Kentucky                 39
# 18              Louisiana                 38
# 19                  Maine                 45
# 20               Maryland                 39
# 21          Massachusetts                 40
# 22               Michigan                 40
# 23              Minnesota                 38
# 24            Mississippi                 39
# 25               Missouri                 38
# 26                Montana                 40
# 27               Nebraska                 36
# 28                 Nevada                 39
# 29          New Hampshire                 43
# 30             New Jersey                 41
# 31             New Mexico                 40
# 32               New York                 40
# 33         North Carolina                 38
# 34           North Dakota                 36
# 35                   Ohio                 40
# 36               Oklahoma                 36
# 37                 Oregon                 40
# 38           Pennsylvania                 42
# 39            Puerto Rico                 44
# 40           Rhode Island                 40
# 41         South Carolina                 40
# 42           South Dakota                 38
# 43              Tennessee                 39
# 44                  Texas                 36
# 45                   Utah                 31
# 46                Vermont                 43
# 47               Virginia                 39
# 48             Washington                 38
# 49          West Virginia                 42
# 50              Wisconsin                 40
# 51                Wyoming                 39

# %%
# List of columns with percentage data to convert to fractions for averaging
columns_to_convert = [
    '18_and_over_population_male',
    '18_and_over_population_female',
    '20_to_24_years',
    '25_to_34_years',
    '35_to_44_years',
    '45_to_54_years',
    '55_to_59_years',
    '60_to_64_years',
    '65_to_74_years',
    '75_to_84_years',
    '85_years_and_over',
]

# Convert the columns to fractions by dividing by 100
age_2022_df[columns_to_convert] = age_2022_df[columns_to_convert] / 100

# Group by 'state' and calculate the average of all numerical columns
state_averages2022_df = age_2022_df.groupby('state').mean().reset_index()

# Convert the specific columns back to plain numbers with one or two decimal places
state_averages2022_df[columns_to_convert] = state_averages2022_df[columns_to_convert] * 100

# Format the specific columns to show as plain numbers with two decimal places
for col in columns_to_convert:
    state_averages2022_df[col] = state_averages2022_df[col].map(lambda x: round(x, 2))

# Display the results
state_averages2022_df
# Out:
#                     state  18_and_over_population_male  \
# 0                 Alabama                        47.60
# 1                  Alaska                        53.20
# 2                 Arizona                        49.64
# 3                Arkansas                        48.75
# 4              California                        49.39
# 5                Colorado                        50.54
# 6             Connecticut                        48.16
# 7                Delaware                        47.70
# 8    District of Columbia                        46.50
# 9                 Florida                        48.38
# 10                Georgia                        47.79
# 11                 Hawaii                        50.70
# 12                  Idaho                        49.85
# 13               Illinois                        48.71
# 14                Indiana                        48.93
# 15                   Iowa                        49.80
# 16                 Kansas                        49.83
# 17               Kentucky                        48.92
# 18              Louisiana                        48.08
# 19                  Maine                        49.00
# 20               Maryland                        47.75
# 21          Massachusetts                        48.17
# 22               Michigan                        49.08
# 23              Minnesota                        49.91
# 24            Mississippi                        47.65
# 25               Missouri                        48.75
# 26                Montana                        50.45
# 27               Nebraska                        49.70
# 28                 Nevada                        50.05
# 29          New Hampshire                        49.70
# 30             New Jersey                        48.38
# 31             New Mexico                        49.33
# 32               New York                        47.92
# 33         North Carolina                        48.06
# 34           North Dakota                        51.10
# 35                   Ohio                        48.83
# 36               Oklahoma                        49.14
# 37                 Oregon                        49.40
# 38           Pennsylvania                        48.75
# 39            Puerto Rico                        46.60
# 40           Rhode Island                        48.10
# 41         South Carolina                        47.86
# 42           South Dakota                        50.60
# 43              Tennessee                        48.27
# 44                  Texas                        49.37
# 45                   Utah                        50.50
# 46                Vermont                        49.20
# 47               Virginia                        48.93
# 48             Washington                        50.18
# 37           11.48            5.80               1.97          40.633333
# 38           11.31            5.93               2.31          41.200000
# 39           11.90            8.60               3.00          44.700000
# 40           11.00            5.70               2.15          40.550000
# 41           11.50            5.84               1.74          40.514286
# 42           11.20            5.00               2.10          38.500000
# 43           10.34            5.29               1.66          39.233333
# 44            8.19            3.97               1.28          35.623684
# 45            7.27            3.58               1.12          32.000000
# 46           12.90            6.60               2.10          43.200000
# 47            9.88            5.24               1.74          39.236364
# 48           10.10            5.01               1.70          38.510000
# 49           12.65            6.45               2.05          42.900000
# 50           11.16            5.50               2.04          40.537500
# 51           11.80            5.40               1.40          39.100000
#
#       year
# 0   2022.0
# 1   2022.0
# 2   2022.0
# 3   2022.0
# 4   2022.0
# 5   2022.0
# 6   2022.0
# 7   2022.0
# 8   2022.0
# 9   2022.0
# 10  2022.0
# 11  2022.0
# 12  2022.0
# 13  2022.0
# 14  2022.0
# 15  2022.0
# 16  2022.0
# 17  2022.0
# 18  2022.0
# 19  2022.0
# 20  2022.0
# 21  2022.0
# 22  2022.0
# 23  2022.0
# 24  2022.0
# 25  2022.0
# 26  2022.0
# 27  2022.0
# 28  2022.0
# 29  2022.0
# 30  2022.0
# 31  2022.0
# 32  2022.0
# 33  2022.0
# 34  2022.0
# 35  2022.0
# 36  2022.0
# 37  2022.0
# 38  2022.0
# 39  2022.0
# 40  2022.0
# 41  2022.0
# 42  2022.0
# 43  2022.0
# 44  2022.0
# 45  2022.0
# 46  2022.0
# 47  2022.0
# 48  2022.0
# 49  2022.0
# 50  2022.0
# 51  2022.0

# %%
# Convert the 'year' column to integer
state_averages2022_df['year'] = state_averages2022_df['year'].astype(int)
state_averages2022_df['median_age(years)'] = state_averages2022_df['median_age(years)'].astype(int)

state_averages2022_df.head()
# Out:
#          state  18_and_over_population_male  18_and_over_population_female  \
# 0      Alabama                        47.60                          52.40
# 1       Alaska                        53.20                          46.80
# 2      Arizona                        49.64                          50.36
# 3     Arkansas                        48.75                          51.25
# 4   California                        49.39                          50.61
#
#    20_to_24_years  25_to_34_years  35_to_44_years  45_to_54_years  \
# 0            6.80           12.86           12.47           12.17
# 1            7.10           15.50           14.30           11.20
# 2            7.11           13.86           12.58           11.61
# 3            6.90           12.62           12.70           11.95
# 4            6.75           14.74           13.83           12.51
#
#    55_to_59_years  60_to_64_years  65_to_74_years  75_to_84_years  \
# 0            6.27            6.73           10.77            5.57
# 1            5.90            5.90            9.40            3.70
# 2            5.66            6.20           10.63            6.42
# 3            6.00            6.60           10.38            5.58
# 4            6.04            5.98            9.14            4.82
#
#    85_years_and_over  median_age(years)  year
# 0               1.69                 39  2022
# 1               0.80                 35  2022
# 2               1.78                 39  2022
# 3               1.78                 39  2022
# 4               1.83                 37  2022

# %%
# Export DataFrame as cleaned csv
state_averages2022_df.to_csv('2022_Census_Age_et.csv', index=False)
